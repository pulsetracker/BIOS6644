# %%
##########################################################################################
#                                                                                        #
#  888888b.  8888888 .d88888b.   .d8888b.     .d8888b.   .d8888b.      d8888      d8888  #
#  888  "88b   888  d88P" "Y88b d88P  Y88b   d88P  Y88b d88P  Y88b    d8P888     d8P888  #
#  888  .88P   888  888     888 Y88b.        888        888          d8P 888    d8P 888  #
#  8888888K.   888  888     888  "Y888b.     888d888b.  888d888b.   d8P  888   d8P  888  #
#  888  "Y88b  888  888     888     "Y88b.   888P "Y88b 888P "Y88b d88   888  d88   888  #
#  888    888  888  888     888       "888   888    888 888    888 8888888888 8888888888 #
#  888   d88P  888  Y88b. .d88P Y88b  d88P   Y88b  d88P Y88b  d88P       888        888  #
#  8888888P" 8888888 "Y88888P"   "Y8888P"     "Y8888P"   "Y8888P"        888        888  #
#                                                                                        # 
##########################################################################################
#
# Read CSV with Pandas
#
##########################################################################################

# %%
##################################################################################################################
#
# YouDo:
#    1) Make a copy of this notebook with your name as a suffix:  
#       BIOS6644_Read_CSV_Pandas_FirstLast.ipynb
#    2) Do all work in this new notebook.
#    3) Submit completed work via GitHub pull request
#
##################################################################################################################

# %% [markdown]
# ## Read Data with Pandas
# If you're going to do some exploratory data analysis, Pandas has wonderful tools including a robust data reader.
#
# In this exercsise, we'll use the Educational Attainment data file mentioned on Canvas [above](https://data-cdphe.opendata.arcgis.com/datasets/cee9e5ea911c4814999de34806474105_3/data):

# %%
import pandas as pd
import pylab as plt
import numpy as np
# %matplotlib notebook

# %%
# Read the data
#datafile = 'C:/Users/rache/Documents/GitHub/BIOS6644/Data/Educational_Attainment_Census_Tracts.csv'
datafile = '../Data/Educational_Attainment_Census_Tracts.csv'
df = pd.read_csv(datafile)

# %%
# Now our data are in a pandas data frame.  You can get a "pretty" view just by printing df
df

# Notice that the column Tract_Name automatically handled the quoted field with commas inside.
# Out:
#       OBJECTID        FIPS                                      Tract_Name  \
# 0            1  8043979000     Census Tract 9790, Fremont County, Colorado
# 1            2  8045951600    Census Tract 9516, Garfield County, Colorado
# 2            3  8069002803    Census Tract 28.03, Larimer County, Colorado
# 3            4  8125963200        Census Tract 9632, Yuma County, Colorado
# 4            5  8069002401    Census Tract 24.01, Larimer County, Colorado
# 5            6  8069002402    Census Tract 24.02, Larimer County, Colorado
# 6            7  8103951200  Census Tract 9512, Rio Blanco County, Colorado
# 7            8  8103951100  Census Tract 9511, Rio Blanco County, Colorado
# 8            9  8049000201       Census Tract 2.01, Grand County, Colorado
# 9           10  8049000202       Census Tract 2.02, Grand County, Colorado
# 10          11  8049000100          Census Tract 1, Grand County, Colorado
# ...

# %%
# We can get a county list in a similarly pithy bit of code
# that works on the data frame

counties = [xx.capitalize() for xx in list(set(df.County))]
counties.sort()
print(", ".join(counties))
# Out:
# Adams, Alamosa, Arapahoe, Archuleta, Baca, Bent, Boulder, Broomfield, Chaffee, Cheyenne, Clear creek, Conejos, Costilla, Crowley, Custer, Delta, Denver, Dolores, Douglas, Eagle, El paso, Elbert, Fremont, Garfield, Gilpin, Grand, Gunnison, Hinsdale, Huerfano, Jackson, Jefferson, Kiowa, Kit carson, La plata, Lake, Larimer, Las animas, Lincoln, Logan, Mesa, Mineral, Moffat, Montezuma, Montrose, Morgan, Otero, Ouray, Park, Phillips, Pitkin, Prowers, Pueblo, Rio blanco, Rio grande, Routt, Saguache, San juan, San miguel, Sedgwick, Summit, Teller, Washington, Weld, Yuma

# %%
# Data Frames have a describe() method that gives a nice summary:
df.describe()
# Out:
#           OBJECTID          FIPS    Tract_FIPS  Population_Total  \
# count  1242.000000  1.242000e+03  1.242000e+03       1242.000000
# mean    625.263285  8.046911e+09  8.046911e+09       4377.229469
# std     361.390928  3.586921e+07  3.586921e+07       2005.786919
# min       1.000000  8.001008e+09  8.001008e+09         97.000000
# 25%     312.250000  8.013014e+09  8.013014e+09       2975.000000
# 50%     625.500000  8.041003e+09  8.041003e+09       4158.000000
# 75%     938.750000  8.069001e+09  8.069001e+09       5499.000000
# max    1249.000000  8.125963e+09  8.125963e+09      15869.000000
#
#        Population_Density_PerLandSquareMile  Education_Population_AgeOver24  \
# count                           1242.000000                     1242.000000
# mean                            3617.088406                     2953.685185
# std                             3591.713958                     1319.196144
# ...

# %%
# Nominal data fields can be nicely 
# summarized with value_counts()
df.County.value_counts()
# Out:
# ARAPAHOE       147
# DENVER         143
# JEFFERSON      137
# EL PASO        130
# ADAMS           96
# WELD            77
# LARIMER         73
# BOULDER         68
# DOUGLAS         61
# PUEBLO          54
# MESA            29
# BROOMFIELD      15
# FREMONT         14
# EAGLE           14
# GARFIELD        11
# MONTROSE        10
# LA PLATA        10
# MORGAN           8
# ROUTT            8
# MONTEZUMA        7
# DELTA            7
# ELBERT           7
# OTERO            7
# TELLER           6
# LOGAN            6
# LAS ANIMAS       6
# CHAFFEE          5
# PARK             5
# PROWERS          5
# SUMMIT           5
#               ...
# ALAMOSA          4
# PITKIN           4
# RIO GRANDE       3
# CLEAR CREEK      3
# GRAND            3
# KIT CARSON       3
# RIO BLANCO       2
# WASHINGTON       2
# LINCOLN          2
# PHILLIPS         2
# COSTILLA         2
# LAKE             2
# BACA             2
# YUMA             2
# CONEJOS          2
# SAGUACHE         2
# ...

# %%
plt.plot(df.Population_Density_PerLandSquareMile, df.Percent_Education_Population_AgeOver24_NoHSDiploma,'.')
plt.xlabel('Population Density')
plt.ylabel('% >= BS Degree')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Hypothesis:
#
# Boulder County has the stereotype of being upper-class and well-educated. This stereotype has some merit as Boulder County houses a large university, NCAR, and is a Silicon Valley satelite office magnet--Twitter, Google and Oracle have offices, to name a few. But is the population of Boulder *that* educated?

# %%
##################################################################################################################
#
# YouDo:
#
# 1) Have a look at this data set. Formulate a simple hypothesis which can be tested using 
#    this data.  Write a verbal description of this hypothesis in the markdown block, 
#    above.
#
# 2) Use the data to argue your conclusion, including at least one visualization which
#    includes enough information to be published in a report (i.e. title, 
#    labeled axes, color legend, etc.  
#
# 3) If you have statisical training, use some form of statistical hypothesis testing 
#       here as appropriate, and write a paragraph interpreting your test and justifying
#       your conclusion.  
#       
#    If not, write an paragraph or two arguing your case and linking your conclusions
#       to the data.
#

# %% [markdown]
# ### Visualization(s) (minimum of 1)
#
# Below I plotted each census tract in Boulder with its percent of people with a bachelors degree or higher. Also, in red, is plotted that state average percent summarized by tract, not county. The average tract in the state has 38% of its citizens with a post-secondary degree.

# %%
#######################################  BEGIN STUDENT CODE  #####################################################

#2) Visualization code
# If in doubt, use matplotlib.   If you want to get fancy, use bokeh, plotly, etc.

# first subset the data to just Boulder County
boulder = df[df.County == 'BOULDER']

# for later testing I'll make an indicator column
df['binary_boulder'] = np.where(df['County']=='BOULDER', 1, 0)

plt.plot(boulder.OBJECTID, boulder.Percent_Education_Population_AgeOver24_Bachelors_Higher,'.')
plt.xlabel('ID')
plt.ylabel('% >= BS Degree')
plt.axhline(y=38, color='r', linestyle='-')
    # it looks like Boulder is all over the place for education attainment
    # plotted with the horizontal line though, we see they're mostly above average

# %%
## Instructor comment:
## I assume that your red line at 38 represents the mean %>=BS Degree?  
## The ID here isn't significant.   1-d data is probably better represented with
##  a histogram.
## plt.hist(boulder.Percent_Education_Population_AgeOver24_Bachelors_Higher)
ovmean = np.mean(df.Percent_Education_Population_AgeOver24_Bachelors_Higher)
print('Overall mean: {}'.format(ovmean))
# %matplotlib notebook
plt.figure()
plt.hist(boulder.Percent_Education_Population_AgeOver24_Bachelors_Higher,15)
plt.axvline(x=ovmean, color='r', linestyle='-')
plt.xlabel('% >= BS Degree in Various Tracts within Boulder County')
# Out:
# Overall mean: 38.47495974235108
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, '% >= BS Degree in Various Tracts within Boulder County')

# %% [markdown]
# ## Analysis
#
# Census tracts in Boulder county have on average 24.2% more people with a bachelor's degree or higher than other counties in the state. This difference is statistically significant with a p-value of <.0001. The stereotype is true: Boulder is actually quite well educated.

# %% [markdown]
# Instructor Comment:   And yet every time I go there I see stupid people everywhere...

# %%
#3) Statisical testing code (as appropriate)

# sourcing code below from: https://scientificallysound.org/2017/05/16/independent-t-test-python/    

from scipy import stats
from math import sqrt
from scipy.stats import t

# Run independent t-test
ind_t_test = stats.ttest_ind(df.Percent_Education_Population_AgeOver24_Bachelors_Higher[df.binary_boulder == 1],
                             df.Percent_Education_Population_AgeOver24_Bachelors_Higher[df.binary_boulder == 0])

# Calculate the mean difference and 95% confidence interval
N1 = 68 #which we know from an earlier code chunk
N2 = 1174 # which is 1242-68
degrees = (N1 + N2 - 2)
std1 = df.Percent_Education_Population_AgeOver24_Bachelors_Higher[df.binary_boulder == 1].std()
std0 = df.Percent_Education_Population_AgeOver24_Bachelors_Higher[df.binary_boulder == 0].std()
std_N1N2 = sqrt( ((N1 - 1)*(std1)**2 + (N2 - 1)*(std0)**2) / degrees) 

diff_mean = df.Percent_Education_Population_AgeOver24_Bachelors_Higher[df.binary_boulder == 1].mean() - df.Percent_Education_Population_AgeOver24_Bachelors_Higher[df.binary_boulder == 0].mean()
MoE = t.ppf(0.975, degrees) * std_N1N2 * sqrt(1/N1 + 1/N2)
    # I'm getting a margin or error == 0 ... caused by last multiplied portion ... unsure how to address that

    ## Instructor comment:
    ## When I ran this without changes, 
    ## I get The difference between groups is 24.2 [19.7 to 28.8] (mean [95% CI])
    
print('The results of the independent t-test are: \n\tt-value = {:4.5f}\n\tp-value = {:4.5f}'.format(ind_t_test[0],ind_t_test[1]))
print ('\nThe difference between groups is {:3.1f} [{:3.1f} to {:3.1f}] (mean [95% CI])'.format(diff_mean, diff_mean - MoE, diff_mean + MoE))

#######################################   END STUDENT CODE   #####################################################
# Out:
# The results of the independent t-test are:
# 	t-value = 10.43773
# 	p-value = 0.00000
#
# The difference between groups is 24.2 [19.7 to 28.8] (mean [95% CI])
