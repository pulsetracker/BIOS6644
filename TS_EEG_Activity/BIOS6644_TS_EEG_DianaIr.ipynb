# %%
##########################################################################################
#                                                                                        #
#  888888b.  8888888 .d88888b.   .d8888b.     .d8888b.   .d8888b.      d8888      d8888  #
#  888  "88b   888  d88P" "Y88b d88P  Y88b   d88P  Y88b d88P  Y88b    d8P888     d8P888  #
#  888  .88P   888  888     888 Y88b.        888        888          d8P 888    d8P 888  #
#  8888888K.   888  888     888  "Y888b.     888d888b.  888d888b.   d8P  888   d8P  888  #
#  888  "Y88b  888  888     888     "Y88b.   888P "Y88b 888P "Y88b d88   888  d88   888  #
#  888    888  888  888     888       "888   888    888 888    888 8888888888 8888888888 #
#  888   d88P  888  Y88b. .d88P Y88b  d88P   Y88b  d88P Y88b  d88P       888        888  #
#  8888888P" 8888888 "Y88888P"   "Y8888P"     "Y8888P"   "Y8888P"        888        888  #
#                                                                                        # 
##########################################################################################
#
# Wrangle EEG Time Series Data
#
##########################################################################################

# %%
##################################################################################################################
#
# YouDo:
#    1) Make a copy of this notebook with your name as a suffix:  
#       BIOS6644_TS_EEG_FirstLast.ipynb
#    2) Do all work in this new notebook.
#    3) Submit completed work via GitHub pull request
#
##################################################################################################################

# %% [markdown]
# ## Get Data
#
#
# Data Description: https://archive.ics.uci.edu/ml/datasets/EEG+Database
#
# Data Set:         https://archive.ics.uci.edu/ml/machine-learning-databases/eeg-mld/

# %%
##################################################################################################################
#
# YouDo:
#
#  From the above link, download the file: SMNI_CMI_TRAIN.tar.gz
#  Unzip it and extract the files to a useful location and set
#  the variables filesloc to point to it like:
#  filesloc = '../BIOS6644/Data/SMNI_CMI_TRAIN/'

filesloc =  '/home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/'

# %%
# Standard imports
import numpy as np
import pandas as pd
import pylab as plt
# %matplotlib notebook

# Some useful extras
import os
import gzip
import datetime as dt

# %% [markdown]
# ## File roundup
#
# The following snippet of code uses the os.walk command to find all files in your filesloc folder.   It then calls the unzip function to unzip anything that needs unzipping

# %%
# Adapted from https://www.tutorialspoint.com/python/os_walk.htm
# & http://xahlee.info/python/gzip.html

def unzip(filename):
    import gzip
    print('Unzipping {}'.format(filename))
    input = gzip.GzipFile(filename, 'rb')
    s = input.read()
    input.close()

    output = open(filename.split('.gz')[0], 'wb')
    output.write(s)
    output.close()

# Finda all the gzipped files and unzip them
tic = dt.datetime.now()

for root, dirs, files in os.walk(filesloc, topdown=False):
    for name in files:
        thispath = os.path.join(root, name)
        if thispath.endswith('.gz'):
            unzip(thispath)

toc = dt.datetime.now()
print('{} seconds to unzip'.format(toc-tic))
# Out:
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.037.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.013.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.012.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.019.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.009.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.047.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.020.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.029.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.007.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.000.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.015.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.033.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.008.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.018.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.022.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.031.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.014.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.021.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.027.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.035.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.005.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.011.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.003.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.041.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.004.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.010.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.006.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.017.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.025.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000375/co2a0000375.rd.023.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.035.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.009.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.018.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.021.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.008.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.002.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.041.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.013.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.011.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.001.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.005.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.047.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.019.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.010.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.020.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.023.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.037.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.055.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.051.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.015.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.016.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.014.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.000.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.006.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.012.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.033.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.029.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.025.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.027.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000370/co2a0000370.rd.031.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.015.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.025.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.027.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.005.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.004.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.041.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.031.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.009.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.047.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.029.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.012.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.007.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.018.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.010.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.002.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.037.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.016.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.023.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.014.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.019.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.013.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.000.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.021.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.001.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.011.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.003.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.033.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.008.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.006.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000345/co2c0000345.rd.017.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.003.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.000.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.018.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.071.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.045.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.016.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.025.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.043.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.049.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.065.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.051.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.075.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.031.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.030.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.024.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.039.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.041.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.011.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.053.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.055.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.007.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.022.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.012.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.028.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.047.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.026.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.015.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.001.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.005.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000344/co2c0000344.rd.032.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.067.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.002.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.032.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.047.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.033.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.000.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.051.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.043.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.071.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.034.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.041.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.024.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.021.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.017.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.029.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.030.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.036.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.055.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.025.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.027.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.083.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.028.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.073.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.016.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.026.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.023.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.065.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.087.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.053.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000337/co2c0000337.rd.089.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.081.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.053.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.005.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.001.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.071.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.049.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.023.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.057.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.061.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.014.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.032.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.019.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.024.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.079.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.018.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.000.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.007.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.059.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.075.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.029.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.077.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.008.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.002.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.030.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.031.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.065.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.055.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.022.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.026.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000347/co2c0000347.rd.047.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.047.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.015.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.031.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.021.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.025.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.016.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.029.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.019.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.041.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.000.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.033.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.009.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.013.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.011.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.037.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.051.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.003.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.004.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.008.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.010.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.012.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.002.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.018.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.001.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.014.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.017.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.007.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.023.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.005.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000371/co2a0000371.rd.006.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.015.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.020.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.016.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.003.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.022.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.023.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.005.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.006.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.021.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.018.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.035.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.019.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.001.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.033.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.027.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.031.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.009.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.007.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.012.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.047.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.041.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.011.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.061.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.008.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.014.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.051.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.065.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.010.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.000.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000341/co2c0000341.rd.013.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.037.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.027.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.003.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.023.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.004.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.031.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.007.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.000.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.029.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.021.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.011.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.017.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.033.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.013.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.001.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.041.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.005.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.047.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.019.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.009.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.014.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.026.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.018.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.025.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.010.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.024.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.008.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.006.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.015.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000346/co2c0000346.rd.028.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.016.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.018.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.000.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.006.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.015.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.014.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.025.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.047.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.007.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.013.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.005.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.037.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.003.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.009.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.012.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.008.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.033.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.019.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.004.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.001.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.002.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.029.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.021.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.051.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.011.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.035.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.023.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.010.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.017.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000338/co2c0000338.rd.027.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.029.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.017.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.025.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.000.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.006.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.041.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.004.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.035.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.023.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.013.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.016.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.033.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.021.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.039.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.008.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.010.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.011.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.027.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.037.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.012.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.009.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.018.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.001.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.003.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.019.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.015.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.002.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.014.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.031.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000369/co2a0000369.rd.047.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.025.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.004.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.055.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.006.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.037.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.009.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.047.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.021.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.011.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.001.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.014.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.031.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.005.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.007.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.008.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.015.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.029.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.010.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.018.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.013.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.012.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.023.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.027.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.019.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.016.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.020.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.002.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.033.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.003.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000342/co2c0000342.rd.041.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.017.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.049.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.031.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.045.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.012.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.028.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.014.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.002.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.007.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.059.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.024.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.025.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.020.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.018.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.039.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.037.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.022.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.041.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.010.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.019.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.055.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.043.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.057.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.000.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.015.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.061.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.009.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.047.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.023.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.027.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.008.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.011.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.016.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.033.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.027.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.010.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.003.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.025.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.015.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.001.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.005.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.023.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.012.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.029.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.000.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.041.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.007.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.019.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.014.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.021.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.018.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.009.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.047.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.006.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.013.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.031.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.004.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.002.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.017.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000372/co2a0000372.rd.037.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.047.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.033.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.018.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.000.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.011.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.017.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.025.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.014.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.003.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.001.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.029.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.004.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.015.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.016.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.006.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.023.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.008.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.021.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.035.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.002.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.013.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.051.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.027.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.012.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.005.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.041.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.037.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.010.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.031.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000378/co2a0000378.rd.019.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.031.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.043.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.049.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.045.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.002.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.038.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.041.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.047.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.071.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.005.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.029.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.012.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.001.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.061.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.003.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.004.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.065.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.034.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.055.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.037.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.035.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.032.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.006.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.011.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.051.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.036.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.039.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.033.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.000.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000377/co2a0000377.rd.030.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.034.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.022.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.005.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.079.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.041.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.077.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.071.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.012.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.053.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.020.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.065.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.007.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.036.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.006.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.000.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.049.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.025.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.004.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.030.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.035.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.043.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.033.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.039.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.055.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.019.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.075.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.029.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.008.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.037.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000339/co2c0000339.rd.047.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.078.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.058.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.016.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.003.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.098.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.044.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.018.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.007.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.064.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.001.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.014.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.050.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.080.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.019.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.000.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.048.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.010.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.005.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.066.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.084.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.076.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.002.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.009.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.012.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.008.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.042.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.004.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.054.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.006.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2c0000340/co2c0000340.rd.108.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.004.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.045.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.037.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.010.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.023.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.039.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.051.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.006.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.012.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.018.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.016.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.033.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.022.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.029.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.041.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.026.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.055.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.061.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.035.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.043.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.031.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.009.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.020.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.015.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.049.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.047.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.011.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.071.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.005.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000365/co2a0000365.rd.008.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.035.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.000.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.027.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.014.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.003.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.001.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.037.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.019.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.013.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.029.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.009.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.010.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.004.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.033.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.012.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.008.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.071.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.002.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.051.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.006.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.011.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.005.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.065.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.007.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.031.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.018.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.041.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.016.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.015.gz
# Unzipping /home/dir0417/Desktop/BIOS6644-master/Data/SMNI_CMI_TRAIN/co2a0000368/co2a0000368.rd.047.gz
# 0:00:13.306218 seconds to unzip

# %%
##################################################################################################################
#
# YouDo:
#
#   In your filesloc folder find the file co2a0000364/co2a0000364.rd.000
#   
#   1) Open this file and examine its structure in a text editor.
#
#   2) use pd.read_csv to ingest this file into a data frame.  Ensure you skip all lines
#      that start with a "#" (pd.read_csv has this capacity built in).
#      It will have a structure like this:
#
##              0    1    2       3
##       0      0  FP1    0  -8.921
##       1      0  FP1    1  -8.433
##       2      0  FP1    2  -2.574
#
#    3) Notice the structure of this data.  The first column seems to be all of the same 
#       number (0), the second column has entries like FP1, the third column appears to 
#       be a counter, and the last column has positive and negative values.
#       These columns represent  
#           a) the "trial" or iteration number of the recording session 
#           b) the "channel" (which EEG sensor), 
#           c) the time the measurement in ms after starting 
#           d) the actual measurment of the EEG sensor in microvolts
#       
#
#       Give these columns the proper names of 'Time', 'Channel', 'Time', and 'uV'
#######################################  BEGIN STUDENT CODE  #####################################################

# 2) 
datafile = os.path.join(filesloc,'co2a0000364/co2a0000364.rd.000')
df=pd.read_csv(datafile  ,sep=' ',skiprows=4, comment='#',header=None)
print(df)

#3)             
df.columns=['Trial','Channel','Time','uV']

#######################################   END STUDENT CODE   #####################################################
# Out:
#        0    1    2       3
# 0      0  FP1    0  -8.921
# 1      0  FP1    1  -8.433
# 2      0  FP1    2  -2.574
# 3      0  FP1    3   5.239
# 4      0  FP1    4  11.587
# 5      0  FP1    5  14.028
# 6      0  FP1    6  11.587
# 7      0  FP1    7   6.704
# 8      0  FP1    8   1.821
# 9      0  FP1    9  -1.109
# 10     0  FP1   10  -2.085
# 11     0  FP1   11  -1.597
# 12     0  FP1   12   0.356
# 13     0  FP1   13   2.309
# 14     0  FP1   14   2.797
# 15     0  FP1   15   2.309
# 16     0  FP1   16   0.356
# 17     0  FP1   17  -0.132
# 18     0  FP1   18  -0.132
# 19     0  FP1   19   0.356
# 20     0  FP1   20   0.844
# 21     0  FP1   21   1.333
# 22     0  FP1   22   2.797
# 23     0  FP1   23   6.215
# 24     0  FP1   24   9.633
# 25     0  FP1   25  10.610
# 26     0  FP1   26   6.704
# 27     0  FP1   27  -0.621
# 28     0  FP1   28  -5.992
# 29     0  FP1   29  -6.480
# ...   ..  ...  ...     ...
# 16354  0    Y  226  15.361
# 16355  0    Y  227  19.755
# 16356  0    Y  228  21.708
# 16357  0    Y  229  20.243
# 16358  0    Y  230  15.361
# 16359  0    Y  231  11.943
# 16360  0    Y  232  12.919
# 16361  0    Y  233  17.314
# 16362  0    Y  234  21.220
# 16363  0    Y  235  22.196
# 16364  0    Y  236  20.732
# 16365  0    Y  237  18.290
# 16366  0    Y  238  17.802
# 16367  0    Y  239  17.802
# 16368  0    Y  240  17.314
# 16369  0    Y  241  14.872
# 16370  0    Y  242  12.431
# 16371  0    Y  243  13.407
# 16372  0    Y  244  17.802
# 16373  0    Y  245  23.173
# 16374  0    Y  246  24.150
# 16375  0    Y  247  20.243
# 16376  0    Y  248  11.454
# 16377  0    Y  249   4.618
# 16378  0    Y  250   3.153
# 16379  0    Y  251   6.571
# 16380  0    Y  252  12.431
# 16381  0    Y  253  15.849
# 16382  0    Y  254  16.337
# 16383  0    Y  255  14.872
#
# [16384 rows x 4 columns]

# %%
##################################################################################################################
#
# YouDo:
#  
#  This data format is quite awkard.  A much better way to display the data would be as a
#  table with columns being the channels (particular EEG sensor), the rows being the time
#  of measurement, and the values being the actual measurements.
#  
#  Building this kind of table from our starting data is called a "pivot", something which 
#  pandas can do for us
#  
#  1) use the pivot method to build a new data frame called dfp which has:
#      columns = channel name (FP1, for example)
#      rows = time (the "counter")
#      values = uV measurements
#
#   2) Make a publication quality visualization of time vs voltage of all channels
#        in this file with a name beginning with the 'C' -- C1, C2, ...
#######################################  BEGIN STUDENT CODE  #####################################################
# 1) 

dfp = df.pivot(index='Time', columns='Channel',values='uV')
dfp.head()

#2) 
# %matplotlib notebook
plt.figure()

for channel in dfp.columns:
    if channel.startswith('C'):
        plt.plot(dfp[channel], label=channel)

plt.legend()
plt.xlabel('Time sample')
plt.ylabel('EEG Amplitude (uV)')
plt.title('EEG "C" Channels from Trial 0')
#######################################   END STUDENT CODE   #####################################################
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'EEG "C" Channels from Trial 0')

# %% [markdown]
# ## File ingest
# This data set has 304 different EEG sensor recordings.  We'd like to scale the data across channels & trials for use in machine learning models later.
#
# The following bit of code also uses os.walk but this time imports all of the files into a big dictionary with one key for each "trial" of the experiment.  The mechanism of import is very similar to what you did above.

# %%
dfs = dict()
tic = dt.datetime.now()
for root, dirs, files in os.walk(filesloc, topdown=False):
    for name in files:
        thispath = os.path.join(root, name)
        if '.rd.' in thispath and not thispath.endswith('.gz'):
            thispatient = thispath.split('.rd.')[1]
            df=pd.read_csv(thispath  ,sep=' ',skiprows=4, comment='#',header=None)
            df.columns=['Trial','Channel','Time','uV']
            dfs[int(thispatient)] = df.pivot(index='Time', columns='Channel',values='uV')
            
toc = dt.datetime.now()
print('{} seconds to read to dfs'.format(toc-tic))
# Out:
# 0:00:42.635191 seconds to read to dfs

# %%
# You can access a particular trial like this:
dfs[3].head()
# Out:
# Channel    AF1    AF2    AF7    AF8    AFZ     C1     C2     C3     C4     C5  \
# Time
# 0       -1.567 -2.543 -3.489  1.811 -0.824 -0.722  0.916 -3.306 -1.923  0.936
# 1        0.875  0.875  2.858  3.764  2.106 -0.234 -1.038  0.112 -1.923  1.424
# 2        1.363  2.340  7.253  1.322  3.082 -2.187 -1.526 -1.353 -2.411  0.936
# 3        0.875  1.851  8.230 -0.631  2.594 -3.652 -2.502 -2.330 -0.458 -0.041
# 4       -0.102  0.875  6.765  0.346  1.617 -2.187 -2.502 -2.818 -2.411 -1.506
#
# Channel  ...    PO8    POZ     PZ     T7     T8    TP7    TP8      X      Y  \
# Time     ...
# 0        ...  3.357 -0.946 -0.692  1.495  1.770  0.692  3.916  0.020  1.170
# 1        ...  4.333 -1.434 -1.668  3.937  6.165  2.157  4.405  1.973  2.635
# 2        ...  4.822 -1.434 -2.157  3.937  7.629  2.157  2.940  1.485  3.123
# 3        ... -2.014 -2.411 -3.133  1.495  5.676  0.203  0.498  0.509  3.123
# 4        ...  3.357 -2.899 -4.110 -1.434  2.747 -2.238 -0.966  0.020  3.123
#
# Channel     nd
# Time
# 0       -2.960
# 1        0.458
# 2        1.923
# 3        1.923
# 4        0.946
#
# [5 rows x 64 columns]

# %%
##################################################################################################################
#
# YouDo:
#  
#  1) 
#   Loop through all the trials and find the global min & max values.
#   
#  2) Make a time vs. voltage visualization of the channel which contains the
#     highest peak from each trial.   I.e.  if the highest measure is in channel FP1,
#     make a plot showing FP1 from every trial.
#
# 
#  3) After re-reading the data documentation, propose an explanation for what you see 
#     in the plot.
#######################################  BEGIN STUDENT CODE  #####################################################

#1) 
globalmax = [dfs[d].max().max() for d in dfs.keys()]
globalmin = [dfs[d].min().min() for d in dfs.keys()]
print(max(globalmax), min(globalmin))

#2) 
fig3 =list(dfs.keys())
bigspike = fig3[globalmax.index(max(globalmax))]

print(dfs[bigspike].max().loc[dfs[bigspike].max()==dfs[bigspike].max().max()])

plt.figure()
for d in dfs.keys():
    plt.plot(dfs[d].X,'.-')
    
    
#3)
#There are two groups from this dataset and they are the control and alcoholic group.  So an EEG is used to find problems related 
#to electrical activity of the brain. I looked up online what an alcoholic group wave would look like. 
#According to this article, alchololics should have EEG signals that are lower than the controls. So we'd expect to 
#see lower peaks of EEG. So the peaks we see at 180 to 250 is probably from the controls.


#######################################   END STUDENT CODE   #####################################################
# Out:
# 346.12 -113.98299999999999
# Channel
# X    346.12
# dtype: float64
# <img src="data:image/png;base64,..." width="640">
