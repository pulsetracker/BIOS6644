# %%
##########################################################################################
#                                                                                        #
#  888888b.  8888888 .d88888b.   .d8888b.     .d8888b.   .d8888b.      d8888      d8888  #
#  888  "88b   888  d88P" "Y88b d88P  Y88b   d88P  Y88b d88P  Y88b    d8P888     d8P888  #
#  888  .88P   888  888     888 Y88b.        888        888          d8P 888    d8P 888  #
#  8888888K.   888  888     888  "Y888b.     888d888b.  888d888b.   d8P  888   d8P  888  #
#  888  "Y88b  888  888     888     "Y88b.   888P "Y88b 888P "Y88b d88   888  d88   888  #
#  888    888  888  888     888       "888   888    888 888    888 8888888888 8888888888 #
#  888   d88P  888  Y88b. .d88P Y88b  d88P   Y88b  d88P Y88b  d88P       888        888  #
#  8888888P" 8888888 "Y88888P"   "Y8888P"     "Y8888P"   "Y8888P"        888        888  #
#                                                                                        # 
##########################################################################################
#
# Wrangle EEG Time Series Data
#
##########################################################################################

# %%
##################################################################################################################
#
# YouDo:
#    1) Make a copy of this notebook with your name as a suffix:  
#       BIOS6644_TS_EEG_FirstLast.ipynb
#    2) Do all work in this new notebook.
#    3) Submit completed work via GitHub pull request
#
##################################################################################################################

# %% [markdown]
# ## Get Data
#
#
# Data Description: https://archive.ics.uci.edu/ml/datasets/EEG+Database
#
# Data Set:         https://archive.ics.uci.edu/ml/machine-learning-databases/eeg-mld/

# %%
##################################################################################################################
#
# YouDo:
#
#  From the above link, download the file: SMNI_CMI_TRAIN.tar.gz
#  Unzip it and extract the files to a useful location and set
#  the variables filesloc to point to it like:
#  filesloc = '../BIOS6644/Data/SMNI_CMI_TRAIN/'

filesloc = 'C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/'

# %%
# Standard imports
import numpy as np
import pandas as pd
import pylab as plt
# %matplotlib notebook

# Some useful extras
import os
import gzip
import datetime as dt

# %% [markdown]
# ## File roundup
#
# The following snippet of code uses the os.walk command to find all files in your filesloc folder.   It then calls the unzip function to unzip anything that needs unzipping

# %%
# Adapted from https://www.tutorialspoint.com/python/os_walk.htm
# & http://xahlee.info/python/gzip.html

def unzip(filename):
    import gzip
    print('Unzipping {}'.format(filename))
    input = gzip.GzipFile(filename, 'rb')
    s = input.read()
    input.close()

    output = open(filename.split('.gz')[0], 'wb')
    output.write(s)
    output.close()

# Finda all the gzipped files and unzip them
tic = dt.datetime.now()

for root, dirs, files in os.walk(filesloc, topdown=False):
    for name in files:
        thispath = os.path.join(root, name)
        if thispath.endswith('.gz'):
            unzip(thispath)

toc = dt.datetime.now()
print('{} seconds to unzip'.format(toc-tic))
# Out:
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.000.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.002.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.007.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.009.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.010.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.012.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.014.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.015.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.017.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.018.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.019.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.020.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.022.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.023.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.024.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.025.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.027.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.028.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.031.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.037.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.039.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.041.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.043.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.045.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.047.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.049.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.055.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.057.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.059.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000364\co2a0000364.rd.061.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.004.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.005.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.006.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.008.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.009.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.010.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.011.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.012.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.015.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.016.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.018.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.020.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.022.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.023.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.026.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.029.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.031.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.033.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.035.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.037.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.039.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.041.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.043.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.045.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.047.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.049.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.051.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.055.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.061.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000365\co2a0000365.rd.071.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.000.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.001.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.002.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.003.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.004.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.005.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.006.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.007.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.008.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.009.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.010.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.011.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.012.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.013.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.014.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.015.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.016.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.018.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.019.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.027.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.029.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.031.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.033.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.035.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.037.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.041.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.047.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.051.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.065.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000368\co2a0000368.rd.071.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000369\co2a0000369.rd.000.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000369\co2a0000369.rd.001.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000369\co2a0000369.rd.002.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000369\co2a0000369.rd.003.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000369\co2a0000369.rd.004.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000369\co2a0000369.rd.006.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000369\co2a0000369.rd.008.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000369\co2a0000369.rd.009.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000369\co2a0000369.rd.010.gz
# Unzipping C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN\co2a0000369\co2a0000369.rd
#       number (0), the second column has entries like FP1, the third column appears to 
#       be a counter, and the last column has positive and negative values.
#       These columns represent  
#           a) the "trial" or iteration number of the recording session 
#           b) the "channel" (which EEG sensor), 
#           c) the time the measurement in ms after starting 
#           d) the actual measurment of the EEG sensor in microvolts
#       
#
#       Give these columns the proper names of 'Time', 'Channel', 'Time', and 'uV'
#######################################  BEGIN STUDENT CODE  #####################################################

# in Notepad file looks to be mostly written in Chinese with some other characters interspersed...

# 2) 
datafile = 'C:/Users/rache/Documents/GitHub/BIOS6644/Data/SMNI_CMI_TRAIN.tar/SMNI_CMI_TRAIN/SMNI_CMI_TRAIN/co2a0000364/co2a0000364.rd.000'
df = pd.read_csv(datafile, sep = ' ', comment = '#', header = None)

#3)     
df.columns = ['trial', 'channel', 'time', 'ekg_mv']

#######################################   END STUDENT CODE   #####################################################

# %%
##################################################################################################################
#
# YouDo:
#  
#  This data format is quite awkward.  A much better way to display the data would be as a
#  table with columns being the channels (particular EEG sensor), the rows being the time
#  of measurement, and the values being the actual measurements.
#  
#  Building this kind of table from our starting data is called a "pivot", something which 
#  pandas can do for us
#  
#  1) use the pivot method to build a new data frame called dfp which has:
#      columns = channel name (FP1, for example)
#      rows = time (the "counter")
#      values = uV measurements
#
#   2) Make a publication quality visualization of time vs voltage of all channels
#        in this file with a name beginning with the 'C' -- C1, C2, ...
#######################################  BEGIN STUDENT CODE  #####################################################
# 1) 
# I don't need trial in the new df so I'll remove it
df = df.drop('trial',axis=1)
#df
dfp = df.pivot_table(df, columns = 'channel', index = 'time')
#dfp
## Instructor comment:
## You'd probably have better luck if you include "values" as well :)
## dfp = data.pivot(index="Time",columns="Channel",values="uV")

#2) 
import matplotlib.pyplot as mplt
# not this
#for column in dfp:
#mplt.plot('time', 'AF1', data = dfp, color = 'skyblue')

# okay not this
#fig, ax = mplt.subplots(dfp.shape[1]-1, sharex = True)
#for i in range(dfp.shape[1]-1):
#    ax[i].plot(dfp[:,0], dfp[:,i+1])

# mplt.show()


# not this
#dfp.set_index('time').plot(subplots = True)

#not this
#columns = dfp2.columns
#y = dfp2.columns[1:]
#for col in y:
#    plt.plot(df['Col1'], df[col])
#    plt.xlabel('x')
#    plt.ylabel('y')
#    plt.legend(y)

#######################################   END STUDENT CODE   #####################################################
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-d752269ef248> in <module>
#      41 #dfp.set_index('time').plot(subplots = True)
#      42
# ---> 43 columns = dfp2.columns
#      44 y = dfp2.columns[1:]
#      45
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
# maybe unstacking will help me plot...
dfp2 = dfp.unstack(level=0)
dfp2

# nope
#dfp2.xs('channel').plot(kind='scatter')

# nope
#dfp2.xs('').plot(kind='scatter')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'channel'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-6084d0044cfc> in <module>
#       3 dfp2
#       4
# ----> 5 dfp2.xs('channel').plot(kind='scatter')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3581         if isinstance(index, MultiIndex):
#    3582             loc, new_index = self.index.get_loc_level(key,
# -> 3583                                                       drop_level=drop_level)
#    3584         else:
#    3585             loc = self.index.get_loc(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in get_loc_level(self, key, level, drop_level)
#    2569                 return indexer, maybe_droplevels(indexer, ilevels, drop_level)
#    2570         else:
# -> 2571             indexer = self._get_level_indexer(key, level=level)
#    2572             return indexer, maybe_droplevels(indexer, [level], drop_level)
#    2573
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in _get_level_indexer(self, key, level, indexer)
#    2650         else:
#    2651
# -> 2652             code = level_index.get_loc(key)
#    2653
#    2654             if level > 0 or self.lexsort_depth == 0:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'channel'

# %% [markdown]
# ## File ingest
# This data set has 304 different EEG sensor recordings.  We'd like to scale the data across channels & trials for use in machine learning models later.
#
# The following bit of code also uses os.walk but this time imports all of the files into a big dictionary with one key for each "trial" of the experiment.  The mechanism of import is very similar to what you did above.

# %%
dfs = dict()
tic = dt.datetime.now()
for root, dirs, files in os.walk(filesloc, topdown=False):
    for name in files:
        thispath = os.path.join(root, name)
        if '.rd.' in thispath and not thispath.endswith('.gz'):
            thispatient = thispath.split('.rd.')[1]
            df=pd.read_csv(thispath  ,sep=' ',skiprows=4, comment='#',header=None)
            df.columns=['Trial','Channel','Time','uV']
            dfs[int(thispatient)] = df.pivot(index='Time', columns='Channel',values='uV')
            
toc = dt.datetime.now()
print('{} seconds to read to dfs'.format(toc-tic))
# Out:
# 0:00:15.132954 seconds to read to dfs

# %%
# You can access a particular trial like this:
dfs[3].head()
# Out:
# Channel    AF1    AF2     AF7    AF8    AFZ     C1     C2     C3     C4  \
# Time
# 0        5.056  2.858  11.169  6.287  4.537 -0.366 -0.427 -0.936 -1.048
# 1        4.567  3.347  11.658  5.310  4.537 -0.366  0.549 -1.424 -0.559
# 2        3.591  5.300   6.775  3.357  4.537 -0.854  1.038 -1.912  0.905
# 3        2.614  6.765   0.427  1.404  5.025 -1.343  1.526 -2.889  2.370
# 4        2.614  6.765  -3.479  0.427  4.537 -1.831  1.526 -3.377  2.858
#
# Channel     C5  ...    PO8    POZ     PZ     T7      T8     TP7    TP8      X  \
# Time            ...
# 0       -1.740  ... -4.751 -4.791 -3.479 -2.533  13.926   6.816  3.733 -2.482
# 1       -1.740  ... -6.704 -5.280 -2.991 -1.068   8.555   3.886  1.780 -1.994
# 2       -1.740  ... -5.239 -5.768 -2.991 -0.580   2.207  -3.927  0.315 -0.529
# 3       -2.228  ... -2.309 -6.256 -2.502 -0.580  -3.164 -11.251 -0.661  1.424
# 4       -2.716  ... -0.844 -6.256 -2.502 -1.556  -6.093 -13.204 -1.638  2.401
#
# Channel      Y      nd
# Time
# 0        2.085  -2.248
# 1        2.574  -5.178
# 2        3.550  -8.596
# 3        4.038 -11.037
# 4        3.550 -11.525
#
# [5 rows x 64 columns]

# %%
##################################################################################################################
#
# YouDo:
#  
#  1) 
#   Loop through all the trials and find the global min & max values.
#   
#  2) Make a time vs. voltage visualization of the channel which contains the
#     highest peak from each trial.   I.e.  if the highest measure is in channel FP1,
#     make a plot showing FP1 from every trial.
#
# 
#  3) After re-reading the data documentation, propose an explanation for what you see 
#     in the plot.
#######################################  BEGIN STUDENT CODE  #####################################################

#1) 

# I am sufficiently frustrated as to not be able to finish this
#
## Unfortunately, missing the "values" in the pivot makes this part completely impossible.
## I think if you re-run it with the dfp = .. line I included will make it make a lot more sense.

#2) 

    
    
#3) 



#######################################   END STUDENT CODE   #####################################################
